# %%
import os
import pandas as pd
Dataset1 = pd.read_excel('EXTENDED1.xlsx')
Dataset2 = pd.read_excel('EXTENDED2.xlsx')
MainDataset = pd.merge(Dataset1, Dataset2, how='left',on = 'ID')
Dataset3 = pd.read_excel('EXTENDED3.xlsx')
MainDataset = pd.merge(MainDataset, Dataset3, how='left',on = 'ID')
MainDataset
# Out:
#             Timestamp_x  Score         ID  Gender              Height  Weight  \
# 0     3/29/2019 0:23:23  0 / 1  121440946    Male        5 ft 10 inch    90.0
# 1     3/29/2019 3:00:10  0 / 1  131440910  Female                5'3"    42.0
# 2    3/28/2019 23:40:52  0 / 1  131440969    Male                 5.4    60.0
# 3    3/28/2019 23:17:47  0 / 1  141340900    Male               5'8''    70.0
# 4    3/24/2019 15:31:24  0 / 1  141440899  Female               156cm    76.0
# 5    3/24/2019 15:32:33  0 / 1  141440945    Male  5 feet 10.5 inches    72.0
# 6    3/31/2019 10:56:25  0 / 1  141440962    Male                 5.6    64.0
# 7     3/30/2019 0:52:07  0 / 1  141440980    Male              5.5 ft    57.0
# 8    3/27/2019 12:44:36  0 / 1  151340894    Male              6 feet    73.0
# 9    3/27/2019 12:41:13  0 / 1  151340897    Male                6.0"    85.0
# 10   3/27/2019 12:39:08  0 / 1  151340898  Female                 5.5    60.0
# ...

# %%
MainDataset.to_excel("output.xlsx",sheet_name='Sheet_name_1')

# %%
Dataset = pd.read_excel('output.xlsx')
Dataset
# Out:
#             Timestamp_x  Score         ID  Gender              Height  Weight  \
# 0     3/29/2019 0:23:23  0 / 1  121440946    Male        5 ft 10 inch    90.0
# 1     3/29/2019 3:00:10  0 / 1  131440910  Female                5'3"    42.0
# 2    3/28/2019 23:40:52  0 / 1  131440969    Male                 5.4    60.0
# 3    3/28/2019 23:17:47  0 / 1  141340900    Male               5'8''    70.0
# 4    3/24/2019 15:31:24  0 / 1  141440899  Female               156cm    76.0
# 5    3/24/2019 15:32:33  0 / 1  141440945    Male  5 feet 10.5 inches    72.0
# 6    3/31/2019 10:56:25  0 / 1  141440962    Male                 5.6    64.0
# 7     3/30/2019 0:52:07  0 / 1  141440980    Male              5.5 ft    57.0
# 8    3/27/2019 12:44:36  0 / 1  151340894    Male              6 feet    73.0
# 9    3/27/2019 12:41:13  0 / 1  151340897    Male                6.0"    85.0
# 10   3/27/2019 12:39:08  0 / 1  151340898  Female                 5.5    60.0
# ...

# %%
columns = [
"Do you need to win in order to derive enjoyment from games and sports?",
"Do you often try to do more than one thing at a time?",
"Do you feel confident when you start any project?",
"Do you get angry instantly if anything goes wrong?",
"Do you find it difficult and frustrating to wait in line?",
"Are you eager to harm yourself to defend your beliefs?", 
"Are you impatient in general?",
"Gender"
]
Dataset = Dataset[columns].copy()
Dataset = Dataset.dropna()

Dataset.head()
# Out:
#   Do you need to win in order to derive enjoyment from games and sports?  \
# 0                                                Yes
# 1                                              Maybe
# 3                                                Yes
# 5                                                Yes
# 6                                                 No
#
#   Do you often try to do more than one thing at a time?  \
# 0                                                 No
# 1                                                Yes
# 3                                                Yes
# 5                                                 No
# 6                                                Yes
#
#   Do you feel confident when you start any project?  \
# 0                                             Maybe
# 1                                             Maybe
# 3                                                No
# 5                                                No
# ...

# %%
Dataset = Dataset.dropna()
Dataset.head()
# Out:
#   Do you need to win in order to derive enjoyment from games and sports?  \
# 0                                                Yes
# 1                                              Maybe
# 3                                                Yes
# 5                                                Yes
# 6                                                 No
#
#   Do you often try to do more than one thing at a time?  \
# 0                                                 No
# 1                                                Yes
# 3                                                Yes
# 5                                                 No
# 6                                                Yes
#
#   Do you feel confident when you start any project?  \
# 0                                             Maybe
# 1                                             Maybe
# 3                                                No
# 5                                                No
# ...

# %%
Dataset = Dataset.replace(['Yes', 'No', 'Maybe'], 
                     [1, 0, 2]) 
Dataset.to_excel("output_1.xlsx",sheet_name='Sheet_name_1')

# %%
Dataset.head()
# Out:
#    Do you need to win in order to derive enjoyment from games and sports?  \
# 0                                                  1
# 1                                                  2
# 3                                                  1
# 5                                                  1
# 6                                                  0
#
#    Do you often try to do more than one thing at a time?  \
# 0                                                  0
# 1                                                  1
# 3                                                  1
# 5                                                  0
# 6                                                  1
#
#    Do you feel confident when you start any project?  \
# 0                                                  2
# 1                                                  2
# 3                                                  0
# 5                                                  0
# ...

# %%
Dataset = Dataset.groupby(['Are you impatient in general?','Gender']).mean()

# %%
Dataset
# Out:
#                                       Do you need to win in order to derive enjoyment from games and sports?  \
# Are you impatient in general? Gender
# 0                             Female                                           0.285714
#                               Male                                             0.800000
# 1                             Female                                           0.909091
#                               Male                                             0.944444
# 2                             Female                                           0.750000
#                               Male                                             1.000000
#
#                                       Do you often try to do more than one thing at a time?  \
# Are you impatient in general? Gender
# 0                             Female                                           0.571429
# ...

# %%
Dataset.plot.kde()

# %%
Dataset.plot.hist()
Dataset.head()
# Out:
#                                Do you need to win in order to derive enjoyment from games and sports?  \
# Are you impatient in general?
# 0                                                                       0.666667
# 1                                                                       0.931034
# 2                                                                       0.923077
#
#                                Do you often try to do more than one thing at a time?  \
# Are you impatient in general?
# 0                                                                       0.814815
# 1                                                                       1.103448
# 2                                                                       1.000000
#
#                                Do you feel confident when you start any project?  \
# Are you impatient in general?
# 0                                                                       1.111111
# ...

# %%
ax1 = Dataset.plot.scatter(x='Do you often try to do more than one thing at a time?',                       y='Do you find it difficult and frustrating to wait in line?',
                      c='DarkBlue')

# %%
X = Dataset.iloc[:, 0:5].values
y = Dataset.iloc[:, 5].values
plt.scatter(x,y, label='skitscat', color='k', s=25, marker="o")
plt.show()

# %%
import matplotlib.pyplot as plt 
from sklearn import preprocessing
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
train_dataset = Dataset.sample(frac=0.9,random_state=0)
test_dataset = Dataset.drop(train_dataset.index)

train_labels = train_dataset.pop("Are you impatient in general?")
test_labels = test_dataset.pop("Are you impatient in general?")

# %%
def build_model():
    model = keras.Sequential([
        layers.Dense(128, activation=tf.nn.relu, input_shape=[len(train_dataset.keys())]),
        layers.Dense(64, activation=tf.nn.relu),
        layers.Dense(1, activation=tf.nn.sigmoid),
    ])
    
    model.compile(optimizer= tf.train.AdamOptimizer(),
              loss='binary_crossentropy',
              metrics=['accuracy'])
    return model

# %%
model = build_model()

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_101 (Dense)            (None, 128)               896
# _________________________________________________________________
# dense_102 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_103 (Dense)            (None, 1)                 65
# ...
# Total params: 9,217
# Trainable params: 9,217
# Non-trainable params: 0
# _________________________________________________________________

# %%
class myCallback(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('acc') > 0.98):
            print("\nReached 99% accuracy so cancelling training!")
            self.model.stop_training = True

# %%
callbacks = myCallback()

# %%
callbacks = myCallback()

model.fit(train_dataset,train_labels,epochs=10,validation_split=0.1,callbacks=[callbacks])
# Out:
# Train on 55 samples, validate on 7 samples
# Epoch 1/10
# 55/55 [==============================] - 1s 13ms/step - loss: 0.7573 - acc: 0.4000 - val_loss: 0.6572 - val_acc: 0.7143
# Epoch 2/10
# 55/55 [==============================] - 0s 90us/step - loss: 0.7004 - acc: 0.4727 - val_loss: 0.6828 - val_acc: 0.4286
# Epoch 3/10
# 55/55 [==============================] - 0s 73us/step - loss: 0.6532 - acc: 0.4727 - val_loss: 0.7145 - val_acc: 0.2857
# Epoch 4/10
# 55/55 [==============================] - 0s 145us/step - loss: 0.6161 - acc: 0.4545 - val_loss: 0.7456 - val_acc: 0.2857
# Epoch 5/10
# 55/55 [==============================] - 0s 91us/step - loss: 0.5898 - acc: 0.4364 - val_loss: 0.7767 - val_acc: 0.2857
# Epoch 6/10
# 55/55 [==============================] - 0s 127us/step - loss: 0.5590 - acc: 0.4364 - val_loss: 0.8100 - val_acc: 0.2857
# Epoch 7/10
# 55/55 [==============================] - 0s 127us/step - loss: 0.5337 - acc: 0.4364 - val_loss: 0.8468 - val_acc: 0.2857
# ...

# %%
eval_model = model.evaluate(test_dataset,test_labels)

print('Loss:',eval_model[0],' Accuracy:',eval_model[1])
# Out:
# 7/7 [==============================] - 0s 286us/step
# Loss: -0.20531074702739716  Accuracy: 0.4285714328289032

# %%
test_predictions = model.predict(test_dataset)
test_predictions = (test_predictions > 0.5)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, test_predictions)
print(cm)
# Out:
# [[3 0]
#  [4 0]]

# %%
#knn

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Importing the dataset
dataset = pd.read_excel('output_1.xlsx')
X = dataset.iloc[:, 1:7].values
y = dataset.iloc[:, 7].values

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

y
# Out:
# array([2, 1, 1, 0, 1, 1, 0, 1, 0, 2, 1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 2,
#        2, 0, 0, 0, 1, 0, 0, 2, 0, 2, 0, 0, 2, 0, 2, 0, 0, 1, 1, 1, 1, 1,
#        1, 0, 2, 1, 0, 1, 2, 2, 1, 1, 1, 1, 1, 0, 2, 0, 0, 2, 0, 1, 1, 1,
#        0, 0, 1], dtype=int64)

# %%
# Fitting K-NN to the Training set
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 15, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[7, 2, 0],
#        [1, 8, 0],
#        [1, 2, 0]], dtype=int64)

# %%
def plot_conf_mat(lTrue, lPred, title):
    """ A function for plotting the confusion matrix given true and predicted labels."""
    cm = confusion_matrix(lTrue.astype(int), lPred.astype(int))
    print(cm)
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title(title)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# %%
plot_conf_mat(y_test, y_pred, 'K=15')
# Out:
# [[7 2 0]
#  [1 8 0]
#  [1 2 0]]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Are you impatient in general?'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-646029219f79> in <module>()
# ...

# %%
import numpy as np
from sklearn.preprocessing import Imputer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
K1 = []
A = []
for K in range(25):
 K_value = K+1
 K1.append(K_value)
 neigh = KNeighborsClassifier(n_neighbors = K_value, weights='uniform', algorithm='auto')
 neigh.fit(X_train, y_train) 
 y_pred = neigh.predict(X_test)
 A.append(accuracy_score(y_test,y_pred)*100)
 print ("Accuracy is ", accuracy_score(y_test,y_pred)*100,"% for K-Value:",K_value)
 plot_conf_mat(y_test, y_pred,K_value)
# Out:
# Accuracy is  57.14285714285714 % for K-Value: 1
# [[8 1 0]
#  [4 4 1]
#  [1 2 0]]
# Accuracy is  66.66666666666666 % for K-Value: 2
# [[9 0 0]
#  [4 5 0]
#  [2 1 0]]
# Accuracy is  66.66666666666666 % for K-Value: 3
# [[7 1 1]
#  [3 6 0]
#  [2 0 1]]
# Accuracy is  66.66666666666666 % for K-Value: 4
# [[8 1 0]
#  [4 5 0]
#  [1 1 1]]
# Accuracy is  52.38095238095239 % for K-Value: 5
# [[6 3 0]
#  [4 5 0]
#  [2 1 0]]
# Accuracy is  52.38095238095239 % for K-Value: 6
# [[6 3 0]
#  [4 5 0]
#  [2 1 0]]
# Accuracy is  57.14285714285714 % for K-Value: 7
# [[7 2 0]
#  [4 5 0]
#  [1 2 0]]
# Accuracy is  66.66666666666666 % for K-Value: 8
# [[7 2 0]
#  [3 6 0]
#  [2 0 1]]
# Accuracy is  57.14285714285714 % for K-Value: 9
# [[6 3 0]
#  [3 6 0]
#  [1 2 0]]
# Accuracy is  61.904761904761905 % for K-Value: 10
# [[7 2 0]
#  [3 6 0]
#  [1 2 0]]
# Accuracy is  66.66666666666666 % for K-Value: 11
# [[8 1 0]
#  [3 6 0]
#  [1 2 0]]
# Accuracy is  66.66666666666666 % for K-Value: 12
# [[7 2 0]
#  [2 7 0]
# ...

# %%
plt.plot(K1,A)

plt.xlabel('K_Value')
plt.ylabel('Accuracy');
